# %%
using Random
using Distributions
using LinearAlgebra
using ForwardDiff
include("../Inversion/Plot.jl")
include("../Inversion/GMNVI.jl")
include("../Inversion/DF_GMVI.jl")
include("../Inversion/GMBBVI.jl")
# Out:
# Gaussian_mixture_BBVI (generic function with 1 method)

# %% [markdown]
# ## Gaussian function
#
# Consider the following inverse problem
#
# $$
# \begin{align*}
# y =
# A\theta
# +\eta
# \qquad
# y =
# \begin{bmatrix}
# y_{(1)}\\
# y_{(2)}
# \end{bmatrix}
# \qquad
# \Sigma_{\eta} = \sigma_\eta^2 I
# \end{align*}
# $$
#
# We focus on the noninformative uniform prior, and hence we are sampling
# $e^{-\frac{1}{2\sigma_\eta^2} (y - A\theta)^T(y - A\theta) }$.
#
# The posterior is a Gaussian with
# $$
# m_{\rm post} = (A^TA)^{-1}A^T y  \qquad
# C_{\rm post} = \sigma_\eta^2(A^TA)^{-1}
# $$
#
# ## Logconcave likelihood function
#
# Consider the following inverse problem
#
# $$
# \begin{align*}
# y =
# \begin{bmatrix}
# (\sqrt{\lambda}\theta_{(1)} -  \theta_{(2)})\\
# \theta_{(2)}^2
# \end{bmatrix}
# +\eta
# \qquad
# y =
# \begin{bmatrix}
# y_{(1)}\\
# y_{(2)}
# \end{bmatrix}
# \qquad
# \Sigma_{\eta} = \sigma_{\eta}^2 I
# \end{align*}
# $$
#
# We focus on the noninformative uniform prior, and hence we are sampling
# $e^{-\frac{1}{2\sigma_\eta^2}\bigl((y_{(1)} - \sqrt{\lambda}\theta_{(1)} + \theta_{(2)})^2 + (y_{(2)} - \theta_{(2)}^2)^2\bigr)}$.

# %%
function G(θ, arg, Gtype = "Gaussian")
    if Gtype == "Gaussian"
        A = arg
        return A*θ
    elseif Gtype == "Logconcave"
        λ = arg
        return [sqrt(λ)*θ[1] - θ[2]; θ[2]^2]
    else
        print("Error in function G")
    end
end


function F(θ, args)
    y, ση, A, Gtype = args
    Gθ = G(θ, A, Gtype )
    return [y[1] - Gθ[1]; y[2] - Gθ[2]]/ση
end


function logrho(θ, args)
    Fθ = F(θ, args)
    return -(Fθ[1]^2 + Fθ[2]^2)/2.0 
end


function dV(θ, args)
    return -logrho(θ, args), 
           -ForwardDiff.gradient(x -> logrho(x, args), θ), 
           -ForwardDiff.hessian(x -> logrho(x, args), θ)
end


function V(θ, args)
    return -logrho(θ, args)
end
# Out:
# V (generic function with 1 method)

# %%
function Gaussian_VI(func_dV, func_V, func_F, μ0, Σ0; N_iter = 100, dt = 1.0e-3)

    N_f = 2
    N_θ = length(μ0)

    T =  N_iter * dt
    N_modes = 1
    x0_w = ones(N_modes)
    x0_mean = reshape(μ0,1,N_θ)
    xx0_cov = reshape(Σ0,1,N_θ,N_θ)
    quadrature_type_GM = "mean_point"

    if func_dV !== nothing
        ngf_obj = GMNVI_Run(
        func_dV, 
        T,
        N_iter,
        # Initial condition
        x0_w, x0_mean, xx0_cov;
        diagonal_covariance = false,
        quadrature_type_GM = quadrature_type_GM,
        quadrature_type = "mean_point")

    end

    if func_F !== nothing
        dfgmvi_obj = DF_GMVI_Run(
        func_F, 
        T,
        N_iter,
        # Initial condition
        x0_w, x0_mean, xx0_cov;
        N_f = 2,
        quadrature_type_GM = quadrature_type_GM,
        quadrature_type = "unscented_transform")

    end
    
    if func_V !== nothing
        bbvi_obj = Gaussian_mixture_BBVI(
        func_V, 
        # Initial condition
        x0_w, x0_mean, xx0_cov;
        diagonal_covariance = false,
        discretize_inv_covariance = true,
        N_ens = 5,
        N_iter = N_iter)

    end


    return ngf_obj, dfgmvi_obj, bbvi_obj
end
# Out:
# Gaussian_VI (generic function with 1 method)

# %%
fig, ax = PyPlot.subplots(nrows=2, ncols=5, sharex=false, sharey=false, figsize=(20,8))

Random.seed!(123)
μ0, Σ0 = [10.0; 10.0], [4.0 0.0; 0.0 4.0]
N_iter = 100


y = [1.0; 2.0]
ση = 0.1
Gtype = "Gaussian"
A = [1.0 1.0; 1.0 2.0]
C_post, m_post = ση^2*inv(A'*A), (A'*A)\(A*y)
func_args = (y, ση, A , Gtype)
func_F(x) = F(x, func_args)
func_V(x) = V(x, func_args)
func_dV(x) = dV(x, func_args)
ngf_obj, dfgmvi_obj, bbvi_obj = Gaussian_VI(func_dV, func_V, func_F, μ0, Σ0; N_iter = N_iter, dt = 5e-1)
objs = (ngf_obj, dfgmvi_obj, bbvi_obj);
visualization_2d(ax[1,:]; Nx=200, Ny=200, x_lim=[-2.0,2.0], y_lim=[-1.0,2.0], func_F=func_F, objs=objs, label=["NGF-VI", "DF-GMVI", "BBVI"])


y = [0.0; 0.0]
ση = 0.1
Gtype = "Logconcave"
λ = 0.1
func_args = (y, ση, λ , Gtype)
func_F(x) = F(x, func_args)
func_V(x) = V(x, func_args)
func_dV(x) = dV(x, func_args)
ngf_obj, dfgmvi_obj, bbvi_obj = Gaussian_VI(func_dV, func_V, func_F, μ0, Σ0; N_iter = N_iter, dt = 2e-1)
objs = (ngf_obj, dfgmvi_obj, bbvi_obj);
visualization_2d(ax[2,:]; Nx=200, Ny=200, x_lim=[-3.0,3.0], y_lim=[-2.0,2.0], func_F=func_F, objs=objs, label=["NGF-VI", "DF-GMVI", "BBVI"])
# Out:
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0007087440443491041, 19965.468890837456, 1070.5781721954875, 0.9998778661568439, 267.6335580567066)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0004409928525210514, 20554.226119643197, 8754.545290395166, 0.9995114947620742, 2266.502708713088)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0015175887186090948, 1192.131860075042, 2621.4053851676836, 0.9989009762123503, 658.2158683466401)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0002332056309126088, 3369.2195742621566, 7865.754780393833, 0.9980464611439889, 4279.6842307722645)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.36851372276290095, 25.91538104094344, 0.9816570187060304, 0.9969481603957967, 0.8511966176874668)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0012395735337246878, 6122.669474532789, 156.89821072472475, 0.9956063449570492, 132.70304939677348)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0014066634928966407, 1798.3928114364496, 512.8498925299237, 0.994021345900628, 315.65276915086247)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.011453416338679549, 87.6188278719866, 1.4613819955075993, 0.992193554301333, 1.4645762445381683)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.001970294815782635, 233.11150156134175, 50.74051282779689, 0.990123421139392, 35.410744969906105)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0001921964178390826, 392.87148444794474, 198.7184356453356, 0.9878114571891864, 260.0914705418718)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.00031457947983051364, 374.65140449625073, 157.9615807140442, 0.9852582328932261, 145.43683746491106)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.00015673437065974173, 445.837442849555, 317.5743300005507, 0.9824643782214019, 596.1196639282942)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0003251808418813767, 423.94881207595, 446.6429231569288, 0.979430582515548, 279.22925078472326)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0006254220796803971, 301.43388232613705, 153.74471274250396, 0.97615759431936, 126.88881020307669)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.000923121548749619, 397.8164708302489, 524.7751010736475, 0.9726462211936998, 397.9609196152843)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.005310588501579811, 134.27217505481468, 128.42389902943341, 0.9688973295173448, 159.9129413790234)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.3457025840499246, 4.04387805506103, 0.8979408333445906, 0.9649118442732201, 1.8672130754442833)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.021223726456284026, 24.335361847846873, 4.250034860431733, 0.9606907488201737, 11.530252912594962)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0