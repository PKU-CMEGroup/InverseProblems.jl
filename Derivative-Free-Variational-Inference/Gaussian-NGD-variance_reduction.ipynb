# %%
using Random
using Distributions
using LinearAlgebra
using ForwardDiff
include("../Inversion/Plot.jl")
include("../Inversion/GMNVI.jl")
include("../Inversion/DF_GMVI.jl")
include("../Inversion/GMBBVI_variance_reduction.jl")
# Out:
# Gaussian_mixture_BBVI (generic function with 1 method)

# %% [markdown]
# ## Gaussian function
#
# Consider the following inverse problem
#
# $$
# \begin{align*}
# y =
# A\theta
# +\eta
# \qquad
# y =
# \begin{bmatrix}
# y_{(1)}\\
# y_{(2)}
# \end{bmatrix}
# \qquad
# \Sigma_{\eta} = \sigma_\eta^2 I
# \end{align*}
# $$
#
# We focus on the noninformative uniform prior, and hence we are sampling
# $e^{-\frac{1}{2\sigma_\eta^2} (y - A\theta)^T(y - A\theta) }$.
#
# The posterior is a Gaussian with
# $$
# m_{\rm post} = (A^TA)^{-1}A^T y  \qquad
# C_{\rm post} = \sigma_\eta^2(A^TA)^{-1}
# $$
#
# ## Logconcave likelihood function
#
# Consider the following inverse problem
#
# $$
# \begin{align*}
# y =
# \begin{bmatrix}
# (\sqrt{\lambda}\theta_{(1)} -  \theta_{(2)})\\
# \theta_{(2)}^2
# \end{bmatrix}
# +\eta
# \qquad
# y =
# \begin{bmatrix}
# y_{(1)}\\
# y_{(2)}
# \end{bmatrix}
# \qquad
# \Sigma_{\eta} = \sigma_{\eta}^2 I
# \end{align*}
# $$
#
# We focus on the noninformative uniform prior, and hence we are sampling
# $e^{-\frac{1}{2\sigma_\eta^2}\bigl((y_{(1)} - \sqrt{\lambda}\theta_{(1)} + \theta_{(2)})^2 + (y_{(2)} - \theta_{(2)}^2)^2\bigr)}$.

# %%
function G(θ, arg, Gtype = "Gaussian")
    if Gtype == "Gaussian"
        A = arg
        return A*θ
    elseif Gtype == "Logconcave"
        λ = arg
        return [sqrt(λ)*θ[1] - θ[2]; θ[2]^2]
    else
        print("Error in function G")
    end
end


function F(θ, args)
    y, ση, A, Gtype = args
    Gθ = G(θ, A, Gtype )
    return [y[1] - Gθ[1]; y[2] - Gθ[2]]/ση
end


function logrho(θ, args)
    Fθ = F(θ, args)
    return -(Fθ[1]^2 + Fθ[2]^2)/2.0 
end


function dV(θ, args)
    return -logrho(θ, args), 
           -ForwardDiff.gradient(x -> logrho(x, args), θ), 
           -ForwardDiff.hessian(x -> logrho(x, args), θ)
end


function V(θ, args)
    return -logrho(θ, args)
end
# Out:
# V (generic function with 1 method)

# %%
function Gaussian_VI(func_dV, func_V, func_F, μ0, Σ0; N_iter = 100, dt = 1.0e-3)

    N_f = 2
    N_θ = length(μ0)

    T =  N_iter * dt
    N_modes = 1
    x0_w = ones(N_modes)
    x0_mean = reshape(μ0,1,N_θ)
    xx0_cov = reshape(Σ0,1,N_θ,N_θ)
    quadrature_type_GM = "mean_point"

    if func_dV !== nothing
        ngf_obj = GMNVI_Run(
        func_dV, 
        T,
        N_iter,
        # Initial condition
        x0_w, x0_mean, xx0_cov;
        diagonal_covariance = false,
        quadrature_type_GM = quadrature_type_GM,
        quadrature_type = "mean_point")

    end

    if func_F !== nothing
        dfgmvi_obj = DF_GMVI_Run(
        func_F, 
        T,
        N_iter,
        # Initial condition
        x0_w, x0_mean, xx0_cov;
        N_f = 2,
        quadrature_type_GM = quadrature_type_GM,
        quadrature_type = "unscented_transform")

    end
    
    if func_V !== nothing
        bbvi_obj = Gaussian_mixture_BBVI(
        func_V, 
        # Initial condition
        x0_w, x0_mean, xx0_cov;
        diagonal_covariance = false,
        discretize_inv_covariance = true,
        N_ens = 5,
        N_iter = N_iter)

    end


    return ngf_obj, dfgmvi_obj, bbvi_obj
end
# Out:
# Gaussian_VI (generic function with 1 method)

# %%
fig, ax = PyPlot.subplots(nrows=2, ncols=5, sharex=false, sharey=false, figsize=(20,8))

    
μ0, Σ0 = [3.0; 3.0], [4.0 0.0; 0.0 4.0]
N_iter = 100


y = [1.0; 2.0]
ση = 0.1
Gtype = "Gaussian"
A = [1.0 1.0; 1.0 2.0]
C_post, m_post = ση^2*inv(A'*A), (A'*A)\(A*y)
func_args = (y, ση, A , Gtype)
func_F(x) = F(x, func_args)
func_V(x) = V(x, func_args)
func_dV(x) = dV(x, func_args)
ngf_obj, dfgmvi_obj, bbvi_obj = Gaussian_VI(func_dV, func_V, func_F, μ0, Σ0; N_iter = N_iter, dt = 5e-1)
objs = (ngf_obj, dfgmvi_obj, bbvi_obj);
visualization_2d(ax[1,:]; Nx=200, Ny=200, x_lim=[-2.0,2.0], y_lim=[-1.0,2.0], func_F=func_F, objs=objs, label=["NGF-VI", "DF-GMVI", "BBVI"])


y = [0.0; 0.0]
ση = 0.1
Gtype = "Logconcave"
λ = 0.1
func_args = (y, ση, λ , Gtype)
func_F(x) = F(x, func_args)
func_V(x) = V(x, func_args)
func_dV(x) = dV(x, func_args)
ngf_obj, dfgmvi_obj, bbvi_obj = Gaussian_VI(func_dV, func_V, func_F, μ0, Σ0; N_iter = N_iter, dt = 2e-1)
objs = (ngf_obj, dfgmvi_obj, bbvi_obj);
visualization_2d(ax[2,:]; Nx=200, Ny=200, x_lim=[-3.0,3.0], y_lim=[-2.0,2.0], func_F=func_F, objs=objs, label=["NGF-VI", "DF-GMVI", "BBVI"])
# Out:
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0007125924467779646, 8036.067493862314, 5612.792051353388, 0.9998778661568439, 1403.1552968009414)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0008254201915141717, 3860.996653345397, 3397.9787340286575, 0.9995114947620742, 1210.9123389973597)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0011916998465348197, 753.5839482208524, 1039.2383353701007, 0.9989009762123503, 838.2152428037289)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0012846671849753688, 75.42200161351175, 1354.2462457800893, 0.9980464611439889, 776.8910678318016)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.005286118796635295, 150.8893134993092, 132.56588303289956, 0.9969481603957967, 188.59738094239788)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.008352952818001073, 53.963997773556926, 43.40581418686976, 0.9956063449570492, 119.19214278470038)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.012203495599538232, 55.50930293699389, 29.57424577624408, 0.994021345900628, 81.45382098046078)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.02655014925821511, 68.94139752264527, 70.89653305954393, 0.992193554301333, 37.370545251994386)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.04585254560658389, 3.5375383974005112, 19.176177260822904, 0.990123421139392, 21.59364126988016)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.05315575216465409, 0.5807357872640728, 1.4424501760030723, 0.9878114571891864, 18.583340785572243)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.14975045294134073, 0.1462924931933745, 3.459290266778742, 0.9852582328932261, 6.5793339087873415)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.2178849855787259, 0.00768766917812845, 1.2227580185942268, 0.9824643782214019, 4.509096281287446)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.0014915898444658807, 0.057169690605977055, 0.979430582515548, 0.6929977486303742)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.00013500451063126474, 0.005016696189767537, 0.97615759431936, 0.8478719144872655)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.323942609453213, 3.987675110382364e-5, 0.043355079795039914, 0.9726462211936998, 3.002526351304764)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.289803103323888e-5, 0.04227824970802546, 0.9688973295173448, 0.462731244914765)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.368195389599972e-6, 0.02428488348507298, 0.9649118442732201, 0.41968488904011375)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.812337709299404e-6, 0.015107678733280878, 0.9606907488201737, 0.19714544892990968)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.3640436061801014e-6, 0.009198598563233497, 0.9562350846503468, 0.13900228218310107)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.781737400352849e-7, 0.004151277999682481, 0.951545951132202, 0.16609369090741247)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.4625376770272247e-7, 0.0003992034124843618, 0.9466245052392699, 0.03373057006111006)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.349254192590885e-7, 0.0005743092141093388, 0.9414719612646832, 0.022111075287105614)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.649659630955604e-7, 0.0006415030452975532, 0.9360895905215687, 0.02578714804112186)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.114560363542463e-8, 0.00010101816267030888, 0.9304787210293689, 0.0016945167338886875)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.6253908107644615e-8, 0.0003139867465184548, 0.9246407371861739, 0.0050427865263501055)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.3017407440943911e-8, 5.662648405707695e-5, 0.9185770794271413, 0.002511649094081612)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.1638563327517194e-8, 0.00010798268873508192, 0.9122892438690908, 0.0024100764038145705)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.3610338955591163e-9, 2.050021981282636e-5, 0.9057787819413594, 0.0014030068080970323)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.434618810439168e-9, 1.0409535560220193e-5, 0.8990473000030095, 0.0008126678681031083)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.4443316810135927e-9, 1.3868597982011044e-5, 0.8920964589464843, 0.00034607007369347604)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.733757133044915e-10, 2.3124629447574018e-6, 0.8849279737878065, 0.00025695432430428074)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.6838618231574656e-10, 1.3635019810301195e-6, 0.877543613243425, 7.655992444293076e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.6095966866240067e-10, 9.477868275222012e-7, 0.8699451992938093, 6.357569737352107e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.6917207048824654e-11, 2.534265671576287e-6, 0.8621346067339042, 7.663818274389109e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.248501854137179e-11, 8.29220099279087e-7, 0.8541137627105514, 4.677157245452382e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.0643511374146138e-11, 4.7125689552345213e-7, 0.8458846462469949, 1.5972670789703387e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.877953909692055e-12, 2.4212812249214586e-7, 0.8374492877545876, 6.037034152924134e-6)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.245594106865043e-12, 2.120265282317433e-6, 0.8288097685318162, 7.909404874970008e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.18949013706558e-12, 3.6626106412355637e-7, 0.8199682202507732, 7.227915585298468e-6)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.393041291507875e-13, 1.7733324403969707e-7, 0.810926824431198, 1.11544710429163e-5)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.975500056442044e-13, 5.2628659205971786e-8, 0.8016878119022197, 3.5075584507528e-6)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.254564482299632e-13, 4.162316144553978e-8, 0.7922534622519335, 1.7504908801271165e-6)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.091281652378084e-13, 8.02317361886477e-8, 0.7826261032649465, 1.3572159376940535e-6)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.832457438454931e-14, 1.0905819368631513e-8, 0.7728081103480313, 1.16393653667659e-6)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.704909483238859e-14, 2.428063191407194e-8, 0.7628019059440306, 9.824322298254294e-7)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.0595795177499417e-14, 1.2368056102648507e-8, 0.7526099589341549, 1.178269770571697e-6)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.652191031264693e-15, 4.606886314078027e-9, 0.7422347840288236, 4.6696885281244856e-7)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.1456772630551786e-14, 4.384946685122353e-9, 0.7316789411471974, 9.022870631530461e-8)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.733255874167808e-15, 1.1319464291095587e-8, 0.720945034785557, 2.4368077311104334e-7)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.8031662568948498e-15, 8.818931000729196e-10, 0.7100357133746821, 9.268357301907955e-8)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.435722162474063e-15, 9.43702670697443e-10, 0.6989536686263912, 5.1698107910534016e-8)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.71324239956196e-16, 8.628177365948929e-10, 0.6877016348694018, 1.3675606009512608e-7)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.696528532343481e-16, 4.414574153752931e-10, 0.6762823883746756, 9.96155916310899e-9)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.7158244520311815e-16, 8.123862134500364e-10, 0.6646987466704154, 1.414720582565514e-8)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.0039704286603506e-16, 2.3590408415698196e-10, 0.6529535678468819, 5.129030472201879e-9)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.580361673049448e-17, 1.8958843745777497e-10, 0.6410497498512029, 3.207263181529253e-9)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.7428748402675475e-17, 2.003654172408395e-11, 0.6289902297723483, 7.654614924366529e-10)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.0707251599125425e-17, 6.367072281941892e-12, 0.6167779831164467, 4.007437351678731e-10)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.684036072284178e-17, 2.7538425825572915e-12, 0.6044160230726253, 1.8488412405171573e-10)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.751397572340232e-17, 2.156955621055684e-12, 0.5919073997695485, 1.359707858399429e-10)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.130466570252318e-16, 1.1416703353582641e-12, 0.5792551995228458, 3.3081256589683596e-11)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.9942646658551385e-16, 2.5637985064199127e-12, 0.5664625440736094, 1.044252925251993e-10)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.063119868794512e-17, 2.3078888171072796e-12, 0.5535325898181503, 5.692588765161114e-11)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.17892563931115e-17, 3.523745729220709e-12, 0.5404685270292066, 1.23860421856709e-10)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.141450319825085e-17, 6.377303986924903e-13, 0.5272735790687895, 1.2946658398496791e-11)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.577566798522238e-17, 4.889583706329264e-13, 0.5139510015928676, 1.0892132079853013e-11)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.0933301379010434e-16, 4.610914361872302e-13, 0.5005040817480835, 7.450243260029288e-12)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.937122951690183e-17, 6.959815923619728e-14, 0.486936137360698, 1.2104921151616948e-12)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.1102230246251566e-17, 2.4810612507028174e-14, 0.4732505161179676, 4.547723886854947e-13)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.1636175437410707e-16, 1.323517583353297e-14, 0.4594505947421514, 1.9683471709851101e-13)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.483800353594514e-17, 1.2668914207184662e-14, 0.44553977815735596, 4.1996398520241754e-13)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.303885926861595e-16, 1.1768953414991417e-14, 0.43152149864942196, 1.7176074997573138e-13)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.0405342821915281e-16, 1.723617160414554e-14, 0.4173992150190578, 3.1475670840746196e-13)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.280369834735101e-17, 1.4083872180297101e-15, 0.40317641172843277, 2.1375828366888324e-14)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.9164205652118056e-17, 9.009779860954466e-16, 0.38885659804143896, 1.3145566892478132e-14)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.1860695009731334e-16, 1.427556172539788e-15, 0.3744433071578313, 2.177057676968952e-14)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.7764956118577414e-16, 3.228718972625549e-16, 0.3599400953414646, 1.1983243550985883e-14)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.0741085019148344e-16, 3.0790305232446013e-16, 0.3453505410428386, 6.8136804731231546e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.393452566852845e-17, 3.985231274991172e-16, 0.3306782440161679, 5.8143151357379205e-15)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.510833468576701e-17, 1.7264217494692542e-17, 0.31592682443119796, 2.621988561689839e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.958081967793456e-17, 2.1979530094899126e-17, 0.3010999219799811, 1.8122763424728602e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.375812773456437e-17, 7.130847356883254e-17, 0.2862011949788372, 2.0022329762728733e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.3972849129904254e-17, 2.3539318345504933e-16, 0.271234319465719, 6.454685336211228e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.855662542527306e-17, 9.634374921385279e-18, 0.2562029882932062, 1.5443903502039631e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.328888034218905e-17, 5.252713426088324e-16, 0.24111091021734643, 1.328055487267943e-14)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.0877388482695902e-16, 1.4581002590132512e-16, 0.22596180898257728, 9.738472135691045e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.522580299999547e-17, 9.852964053569282e-17, 0.2107594224029476, 3.692803979543846e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.188600426433445e-17, 1.0656952124867567e-16, 0.1955075014398675, 1.797614839268109e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.3773926372158861e-16, 6.666151066385387e-17, 0.18020980927661542, 3.516594285601163e-15)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.530527749616485e-17, 8.770860169495749e-17, 0.16487012038982862, 2.8319250820895036e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.165046692217056e-16, 4.536475258495114e-16, 0.149492219618207, 1.2518020568709428e-14)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.906783589979253e-17, 2.046848557937851e-16, 0.13407990122866142, 4.4029653559139615e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.1102230246251565e-16, 7.488470178734704e-17, 0.11863696798013491, 4.753959378177126e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.7020845086023683e-16, 6.979054621652187e-17, 0.10316723018532914, 1.8199485973296476e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.595094054341031e-17, 9.326855479222741e-17, 0.08767450477056654, 1.5566917267843769e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.804007116436462e-17, 1.4310291918616446e-16, 0.0721626143340204, 2.0970820426160897e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.930136612989093e-17, 7.205975906108636e-17, 0.05663538620254625, 5.803987211586361e-15)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.2786376445539788e-16, 2.3253026878787216e-17, 0.04109665148734711, 7.592055984136204e-16)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.687116766346677e-17, 5.0261316642678866e-17, 0.02555024413870244, 7.350587775840322e-16)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.944351721668025e-17, 1.5790989162223282e-16, 0.010000000000000061, 6.5824076765975514e-15)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 3.497679387861093e-5, 45561.0036182745, 116743.10817040896, 0.9998778661568439, 28586.89305906597)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0002331059636166577, 4104.905375490385, 9657.764225962064, 0.9995114947620742, 4287.798901643584)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0010720230622316015, 356.83922586909233, 1162.7560069641097, 0.9989009762123503, 931.7905662709952)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.0014718133467704429, 110.74556967522868, 581.1865798134894, 0.9980464611439889, 678.1066793109147)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.06867358924728133, 35.497809229717184, 6.125124930474933, 0.9969481603957967, 14.51719898906062)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.022694590299904047, 47.746768711296696, 178.17901256999218, 0.9956063449570492, 43.86976507618464)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.09887327024596788, 9.244741102192712, 22.233756140043536, 0.994021345900628, 10.053489112151267)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.18972096108068517, 6.975001330366437, 1.1790831894608158, 0.992193554301333, 5.2297518874541735)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.16470886119873754, 8.309646428184825, 5.533041531637846, 0.990123421139392, 6.011354907886286)
# [ Info: ("iter = ", 10, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.8548869220093275, 1.0749748870187235, 0.9878114571891864, 1.7981060875139803)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.09153521877134158, 0.04759085781240252, 0.9852582328932261, 0.26050641561982757)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.01666890597930903, 0.13528975310256552, 0.9824643782214019, 1.6372627516009979)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.031013725291358332, 0.08592608809689686, 0.979430582515548, 0.16758846492032714)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.06536021806900508, 0.29615723462627125, 0.97615759431936, 0.44860210820040486)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.0014165774310877705, 0.09044264899344236, 0.9726462211936998, 0.17485012117565193)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.0034100443090090454, 0.08410198650966674, 0.9688973295173448, 0.20027894163581214)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.004808901924666008, 0.06814104259155188, 0.9649118442732201, 0.16488187597573054)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.00018104731221896137, 0.0621605045708947, 0.9606907488201737, 0.10902572701083042)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.00035229492032712106, 0.1917686974285763, 0.9562350846503468, 0.33191689292788373)
# [ Info: ("iter = ", 20, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.018581665407463e-5, 0.04339295621860589, 0.951545951132202, 0.06956424569841427)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 0.00010143310951554178, 0.37279076198956745, 0.9466245052392699, 1.043240044663359)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.933053005181173e-5, 0.10805864966162382, 0.9414719612646832, 0.2981263047196808)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.6514168334068663e-5, 0.3297180646640399, 0.9360895905215687, 0.547361499000041)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.270524508730724e-6, 0.07398409488003209, 0.9304787210293689, 0.2038659493845396)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.867483524686505e-6, 0.11415101564636532, 0.9246407371861739, 0.21972757679006324)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.219567303318491e-7, 0.05558137750057483, 0.9185770794271413, 0.13042216732488843)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.43465908155755845, 3.2518851259058415e-6, 1.2950719255747696, 0.9122892438690908, 2.098861573534806)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.5413365118350876e-7, 0.03640223756130998, 0.9057787819413594, 0.12291292166781187)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.096186712005304e-7, 0.19538842062726655, 0.8990473000030095, 0.9789811455283411)
# [ Info: ("iter = ", 30, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.564991710731187e-7, 0.19361081485961287, 0.8920964589464843, 0.7189522657160569)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.788477765330259e-8, 0.012008489772094245, 0.8849279737878065, 0.0492859261410621)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.3247919023693481e-7, 0.08738084757340554, 0.877543613243425, 0.2296097319400265)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.922395672781593e-7, 0.2584472063718756, 0.8699451992938093, 0.5750643094314168)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.7815526943933364e-8, 0.26406465273584906, 0.8621346067339042, 0.7013973534716159)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.75014936702668e-8, 0.015327423561315414, 0.8541137627105514, 0.1443600545642123)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.598921774289614e-9, 0.03404685422615128, 0.8458846462469949, 0.07067288963212869)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.296809446874035e-9, 0.05106358290964266, 0.8374492877545876, 0.13746572337291083)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.24096007959749688, 4.4076620296365495e-8, 2.05089105257074, 0.8288097685318162, 3.439614437031527)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.6317574118644062e-9, 0.1491967306672665, 0.8199682202507732, 0.545232076656919)
# [ Info: ("iter = ", 40, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.2565185252651973e-9, 0.16820806361831014, 0.810926824431198, 0.4173957052068094)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.5548391445005712e-10, 0.048083164762320364, 0.8016878119022197, 0.19667389811095135)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.175269293889499e-10, 0.14328863375439746, 0.7922534622519335, 0.34364785328456665)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.4315116492096166e-10, 0.08451310720313386, 0.7826261032649465, 0.1695411508163397)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.7567392688686165e-11, 0.054825505183947, 0.7728081103480313, 0.18614848070481588)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.80364128232285e-11, 0.14165974021476377, 0.7628019059440306, 0.24376741471157487)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.6150853722779142e-11, 0.05395424217650066, 0.7526099589341549, 0.10764190478730894)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.19734134986438812, 1.4846939547427292e-11, 1.631269862324549, 0.7422347840288236, 3.7611721240322074)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.530480517321398e-12, 0.10736807423960905, 0.7316789411471974, 0.5445772593091693)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.24621747846540532, 4.143302541460937e-12, 0.5315781223998909, 0.720945034785557, 2.928082276201416)
# [ Info: ("iter = ", 50, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.394683587820992e-12, 0.048532976949645305, 0.7100357133746821, 0.4755391762271059)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.540387679436396e-13, 0.10031095326905658, 0.6989536686263912, 0.24580536217521715)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.466167205633808e-13, 0.10844108356406022, 0.6877016348694018, 0.49544293101633213)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.398511081682959e-14, 0.08398982357322399, 0.6762823883746756, 0.15442265505195105)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.7648798062508696e-14, 0.08451185193531126, 0.6646987466704154, 0.15456467046778422)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.105592377324774e-14, 0.09277810415521652, 0.6529535678468819, 0.21009375832792673)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.8561135148303953e-14, 0.6934437259488698, 0.6410497498512029, 1.2700057994852545)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.186327505286579e-15, 0.15303486434735777, 0.6289902297723483, 0.45726742346972965)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.3871650079809946e-15, 0.10594170988258134, 0.6167779831164467, 0.2789753813234803)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 4.722056169215781e-15, 0.07564357541632925, 0.6044160230726253, 0.2853121167200094)
# [ Info: ("iter = ", 60, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.59562340761729e-15, 0.07742118914447906, 0.5919073997695485, 0.1773880802171654)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.528943815720884e-15, 0.1469982976316013, 0.5792551995228458, 0.27820409439720417)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.1887955513483205e-16, 0.020441820960062893, 0.5664625440736094, 0.05147521821506507)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.571358835681685e-16, 0.3475997003577607, 0.5535325898181503, 0.5613083485180647)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.6910223854471495e-17, 0.3925577570387049, 0.5404685270292066, 0.6628516881435884)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.762389979508782e-17, 0.271075391607941, 0.5272735790687895, 0.6091911517753132)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.8435583831733385e-17, 0.021145467043134338, 0.5139510015928676, 0.1665911072795025)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.144196810752504e-17, 0.0656100008334386, 0.5005040817480835, 0.14513420717985548)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.160723346098896e-17, 0.39389147572466476, 0.486936137360698, 0.6749267089204771)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.165681306894467e-16, 0.17000829448111607, 0.4732505161179676, 0.3854692370409953)
# [ Info: ("iter = ", 70, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.1645337383792426, 3.552713678800501e-17, 1.7962750165423536, 0.4594505947421514, 2.7924400142367105)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.19955543618225494, 1.988401765949869e-17, 0.9037767808390252, 0.44553977815735596, 2.232661693818465)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 2.6737711109153338e-17, 0.17681160036724847, 0.43152149864942196, 0.5474913468500064)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 6.11026247635183e-17, 0.2116438146839367, 0.4173992150190578, 0.4839113553030573)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.583218758733536e-17, 0.051442750564419805, 0.40317641172843277, 0.22871819118565132)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.17074969564413175, 2.8092152890302194e-17, 1.0562940250617678, 0.38885659804143896, 2.2773487037533293)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 9.326534230477075e-17, 0.1323171944936668, 0.3744433071578313, 0.3567619818713669)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.6046107760610657e-17, 0.09619758165116185, 0.3599400953414646, 0.19179188995865093)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.790180836524724e-17, 0.017986614776492337, 0.3453505410428386, 0.15310957436585224)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.7763568394002505e-17, 0.06933485718287978, 0.3306782440161679, 0.14562718853249176)
# [ Info: ("iter = ", 80, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.3336944414291994e-17, 0.04332705653107233, 0.31592682443119796, 0.07245503202750071)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.065703529144609e-17, 0.04399852650591624, 0.3010999219799811, 0.1230523086131381)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.3986982842628625e-17, 0.012166447956168632, 0.2862011949788372, 0.04180287035452091)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.44760245974182e-18, 0.018417291773545515, 0.271234319465719, 0.09255505739303649)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 5.4615751371440004e-17, 0.04797436781112923, 0.2562029882932062, 0.0816759960038415)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.4185898829873514, 1.790180836524724e-17, 0.15511452343445392, 0.24111091021734643, 0.576007495681954)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 3.6146242879064217e-17, 0.017083796514217556, 0.22596180898257728, 0.14018640265150267)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 7.550332863779066e-18, 0.034607644276953294, 0.2107594224029476, 0.10913521358579378)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.031976365714705246, 4.636427468134552e-17, 3.9332392581228786, 0.1955075014398675, 6.114125138053378)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.957958846236168e-17, 0.03588659283294253, 0.18020980927661542, 0.07943304871750788)
# [ Info: ("iter = ", 90, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.350644602892852e-17, 0.057160140188376535, 0.16487012038982862, 0.09748426847000577)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 1.489520491948364e-17, 0.13038148374946634, 0.149492219618207, 0.21173421782317958)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.19113785869852004, 3.722145839155691e-17, 0.3960335577973054, 0.13407990122866142, 0.7014827001915115)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.5, 8.082545620880531e-18, 0.07160894667757334, 0.11863696798013491, 0.14903292593861164)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.49997103426135864, 2.8435583831733385e-17, 0.09679323998995079, 0.10316723018532914, 0.20634641432327203)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.19952088766804688, 2.7217452008024306e-17, 0.046280009509093556, 0.08767450477056654, 0.439425193999914)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.03191293705100036, 3.3820826609804604e-17, 1.3325229906857154, 0.0721626143340204, 2.2612338757381263)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.32007749738494135, 6.661338147750939e-18, 0.07676296639752385, 0.05663538620254625, 0.1769427300115187)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.19188095024223947, 7.273443782444745e-17, 0.10894978407134982, 0.04109665148734711, 0.21417786098862227)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.18829804660137933, 4.9051256466313745e-17, 0.06389317992555378, 0.02555024413870244, 0.1356904365173339)
# [ Info: ("iter = ", 100, " / ", 100)
# [ Info: ("dt, |dm|, |dC|, annealing_dt, |C| = ", 0.026645569544238062, 3.3820826609804604e-17, 0.21011709847585347, 0.010000000000000061, 0.37529691318467234)
# Figure(PyObject <Figure size 2000x800 with 10 Axes>)
# PyObject <matplotlib.legend.Legend object at 0x0000023DE4BCBAD0>
